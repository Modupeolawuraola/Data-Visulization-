# %%
import numpy as np 
import pandas as pd 
import seaborn as  sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df1= pd.read_csv('df1', ind
ex_col=0 )

# %%
df1  #reads a time series
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
#for non time series 
df2 = pd.read_csv('df2')

# %%
df2  #non time series data
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
#pandas can take directly the histogram of the data in our time series data 
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
#when p[andas perform built in function, its add matplolib under ]
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
#one method of calling pandas visulization built in functions 
df1['A'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#another method of calling data visulization built in function 
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#another type of pandas data vilsulization is .area 
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
#using alpha to specify if you want so much transparency 
df2.plot.area(alpha= 0.4)
# Out:
# <AxesSubplot:>

# %%
#barplot 
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked= True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#doing line plot for pandas 
#calling df1 table 
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(figsize=(12, 3), lw= 2)
# Out:
# <AxesSubplot:>

# %%
#specifying the x and y asxis 
#df1.plot.line(x= df1.index, y='B')

# %%
#plotting a scatter plot library  #c is another argument 
s#showing by color 
#adding colormap with cmap
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#showing by size   #times 100 to increase the size 
df1.plot.scatter(x='A', y='B', s=df1['C']*100 )
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
#for bivariant data, you can dp heaxgonal dimension plot 
df= pd.DataFrame(np.random.randn(100, 2), columns=['A', 'B'])

# %%
df  #bivariant data
# Out:
#            A         B
# 0   0.121022 -0.369833
# 1  -0.104559  0.855894
# 2   0.528606 -0.162794
# 3   0.378159 -3.940640
# 4  -0.722160  1.056970
# ..       ...       ...
# 95  0.793499  0.164064
# 96  0.284519  0.157379
# 97 -1.541488  0.533058
# 98  0.794364  0.560280
# 99  1.368400 -0.615155
#
# [100 rows x 2 columns]

# %%
df.plot.hexbin(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#changing the grid size 
df.plot.hexbin(x='A', y='B', gridsize=25)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#addimg colour usinmg the cmap 
df.plot.hexbin(x='A', y='B', gridsize=25, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
#having a density using kde 
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#comparing the entire dataframe across all the data 
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
Pandas inbuilt  help in to have total control on our visualization,
