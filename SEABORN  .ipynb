# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a statistical plotting library, it is designed to work well with pandas object oriented. it is built on top of matplotlib

# %%
Distribution Plot:

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
Distribution plot helps to show univariant/one-variable set of observation in a set of dataset.
    Distribution helps to visualize aour data using histogram
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_17688/1918075492.py", line 1
#     Distribution plot helps to show univariant/one-variable set of observation in a set of dataset.
#                  ^
# SyntaxError: invalid syntax

# %%
#plotting on one column in the set of observation 
sns.distplot(tips['total_bill'])


#we get a histogram with a KDE- kernel density expendition
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
#removing kde from the picture above 
sns.distplot(tips['total_bill'], kde=False)

#checking distribution where the total bills lies 
#this shows most of the total bills are between 10 dollars and 20 dollars
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
#checking numbers of beens 
sns.distplot(tips['total_bill'], kde=False, bins=40)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# Joint plot is basically bivarant dataswet in an observation, its allows us to match up two distplot with kind augment,
# sccatter,
# . kde,
# . reg ;
# . hxe
# . resid

# %%
#talking about jointplot

#you can essentially combine two distribution plot 
#scatter is like a default 

sns.jointplot(x= 'total_bill', y='tip', data=tips)

#this visualization has histogram and scatter plot,  saying tip and total bills are proportionate , 
#as you go higher in total bills, its will makes tips to be higher

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.jointplot(x= 'total_bill', y='tip', data=tips, kind='hex')
#joint also used kind argument, with hexagon distribution representation. less point looks fainter,
#less point looks faint , while more point lookers thicker

# %%
#plotting jointplot for regression 
sns.jointplot( x='total_bill', y='tip', data=tips, kind= 'reg')

# %%
#sns.jointplot(x='total_bill', y='tip', data='tips', kind='resid')

# %% [markdown]
# PAIRPLOT
#
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).its support for categorical dataframe
# the larger the dataframe , the more time pairplot its takes.

# %%
sns.pairplot(tips)

# %%
#you can add hue agrument + categorical columns 
sns.pairplot(tips, hue='sex')

# %%
#adding pallete, which allows you to colour your graph 
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %% [markdown]
# RUGPLOT
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot

# %%
#rugplot for passing a single column 
sns.rugplot(tips['total_bill'])
#the main different between rugplot and distplot is that distplot has a bins to clearly defferiate the values
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# kdeplot
# kdeplots are Kernel Density Estimation plots. These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # CATEGORICAL PLOT

# %%
import seaborn as sns 
# %matplotlib inline

# %%
import numpy as np

# %%
tips= sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
basic categorical data are barplot, 
barplot is a general graph that allows us to aggregate the categorical data based on dataset given

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#checking for SDT of this distribution 
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#countplot for counting the catergorical value 
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
boxplot used to show categorical data, boxplotot is usedd to show a bunch odf categorical data,

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
#this boxplot shows the quartiles
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#futher splitting of our box plot 
#hue is used for adding categorical data set , and the categorical data is smoker 
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#violin plox play a very smiliar role to a boxplot, it is used for categorical dataset, 
#showing distribution of some sort of data across a category 
#violin plot allows us to plot across all the datapoint across our data, it is showing the density across 
#its allows you to reveal more information of the datapoint itselfs, violin plot is a little harder to read than boxplot 
#both violin plot and box plot are very related to each other, 
sns.violinplot(x= 'day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#getting alot more information in violin plot by splitting 
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
Stripplot is among the simplest plot in seaborn, it is used for categorical dataset, 
#in stripplot one variable is categorical and the other is continous data 
#stripplot is a scatterplot in disguise, used in categorical data
#one issue with stripplot is you cant reallt tell, which stack is on top of each other 
#jitter helps to add a random noise to seperate some of this points

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True, hue='sex', split=True)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#combining the stripplot + scatterplot +violin plot = swarmplot
#swapplot shows a lot of information but doesnt fit to a very large number cases. 
#they also takes a lot of conmputations to asrrange them 
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#plotting swamplot and violin plot on top of each other 
sns.violinplot(x= 'day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#factorplot, is a general plot, 
#in factorplot, the kind describe the factor plot itself 
sns.factorplot(x='day', y='total_bill', data=tips, kind='bar')
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#factorplot, is a general plot, 
#in factorplot, the kind describe the factor plot itself 
sns.factorplot(x='day', y='total_bill', data=tips, kind='violin')
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Matrix Plot:
#     creating matrix plot primamrily heat map

# %%
import seaborn as sns 
# %matplotlib inline 
tips= sns.load_dataset('tips')

flight= sns.load_dataset('flights')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#heatmaps is a primarily way of showing matrix plot data 
#to work probably your data should always be in a matrix form, 
#creating a matric form data through pivot table, or correlation 

tc= tips.corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
#labelling or annotating in heat maps 
sns.heatmap(tc, annot=True)
# Out:
# <AxesSubplot:>

# %%
#adding colors or color specifications in heat maps 
sns.heatmap(tc, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#creating pivot table flight 
fp= flight.pivot_table(index= 'month', columns='year', values = 'passengers')

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp)
#this shows more flight are in jun, july and august
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp, cmap='magma', linecolor='white', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
#using another colour 
sns.heatmap(fp, cmap='coolwarm', linecolor='black', linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
#cluttermap, to produce higher version of this heat map 
sns.clustermap(fp)

# %%
sns.clustermap(fp, cmap='coolwarm')

# %%
#cluttermaps shows and clusters similar objects 
sns.clustermap(fp, cmap='coolwarm', standard_scale=1)

# %% [markdown]
# # GRIDS

# %%
#to create subplot based on our capability
import seaborn as sns 
# %matplotlib inline 

iris= sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#calling for iris specis and unique values 
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)  #automatic

# %%
#pairplot is simplified version pof pair grid
g =sns.PairGrid(iris)  #you design by yourself , having more control on it

# %%
#mapping other plot with paigrid
g.map(plt.scatter)  #using map to sepcify

# %%
#passing other function with map function 
f= sns.PairGrid(iris)  #to have typical control on which type of plot you wanted and specify  them through mapping 
f.map_diag(sns.displot)
f.map_upper(plt.scatter)
f.map_lower(sns.kdeplot)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
tips #loadi ng tips dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips, col='time', row='smoker')

# %%
#mapping on to of facetGrid plot, x-axiz represnt total bill , while the col is time and smoker  
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(sns.displot, 'total_bill')
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
#mapping for a plot that needs , more than one argument 
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# # REGRESSION PLOT

# %%
SEABORN has many built in capabilities for regression plot. 
lmplot allows you to dislay different plot in machince learning using different seaborn ,

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#using ln plot to make a very simple linear regression plot , 
sns.lmplot(data=tips, x='total_bill', y='tip')

# %%
#using lmplot to make a very simple linear regression and specifing 'hue'
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex')

# %%
#you can beginers to pass in matplolib markers and markerstype 
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', markers=['o','v'])

# %%
#passing matplotlib parameter into more directly in the lmplot  to increase the scatterplot markers 
sns.lmplot(data=tips, x="total_bill", y='tip', hue='sex', markers=['o', 'v'], scatter_kws={'s':100})

# %%
#categoring it using sex 
sns.lmplot(data=tips, x='total_bill', y='tip', col='sex')

# %%
#grouping in rows using time 
sns.lmplot(data=tips, x='total_bill', y='tip', col='sex', row='time')

# %%
#plotting more col
sns.lmplot(data=tips, x='total_bill', y='tip', col='day', row='time', hue='sex')

# %%
#eliminating row back
sns.lmplot(data=tips, x='total_bill', y='tip', col='day', hue='sex')

# %%
#chaning the aspect ratio(ratio between the height and width)
sns.lmplot(data=tips, x='total_bill', y='tip', col='day', hue='sex', aspect=0.6, size=8)
# Out:
# C:\Users\HP\anaconda3.1\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # STYLE AND COLOR IN SEABORN

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#seaborn has a style argumentg that allows to set  your styles 
sns.set_style('dark')   #setting a dark background 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')  #getting ticks label  at the edge of the graph 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('darkgrid')  #getting darkgreen background of the graph 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('whitegrid')  #getting white grid  background of the graph 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#removing spins from the top, button and side 
sns.set_style('ticks')  #getting ticks label  at the edge of the graph 
sns.countplot(data=tips, x='sex')
sns.despine()  #removimg other spines

# %%
#continue to remove the left and button spine , top and right is true by default 
sns.set_style('ticks')  #getting ticks label  at the edge of the graph 
sns.countplot(data=tips, x='sex')
sns.despine(left=True, bottom=True)

# %%
#Size and aspect (width snd legth)
plt.figure(figsize= (12, 3))  #using matplolib to set fig size and shape 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#scaling and contexting, 
sns.set_context('poster')  #thinking its gonna be put in a poster  
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_context('poster', font_scale= 3)  #getting ticks label  at the edge of the graph (to mame it larger) 
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#setting the context to a note book 
sns.set_context('notebook')  #another type of context size ,
sns.countplot(data=tips, x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#pattelee and colors in seaborn 
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', palette='coolwarm')

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', palette='seismic')
